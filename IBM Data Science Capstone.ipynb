# %% [markdown]
# ## This is my Notebook for the IBM Data Science Capstone Project on Coursera

# %%
#Import needed libraries for the notebook
import pandas as pd
import numpy as np

# %%
"Hello Capstone Project Course"
# Out:
# 'Hello Capstone Project Course'
